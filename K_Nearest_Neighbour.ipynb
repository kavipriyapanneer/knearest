# %% [markdown]
# <a href="https://colab.research.google.com/github/kavipriyapanneer/knearest/blob/main/K_Nearest_Neighbour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Classified Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0           0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608
# 1           1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450
# 2           2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781
# 3           3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128
# 4           4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727
#
#         FDJ       PJF       HQE       NXJ  TARGET CLASS
# 0  0.759697  0.643798  0.879422  1.231409             1
# 1  0.675334  1.013546  0.621552  1.492702             0
# 2  1.626351  1.154483  0.957877  1.285597             0
# 3  1.409708  1.380003  1.522692  1.153093             1
# 4  1.115596  0.646691  1.463812  1.419167             1

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'WTT', 'PTI', 'EQW', 'SBI', 'LQE', 'QWG', 'FDJ', 'PJF',
#        'HQE', 'NXJ', 'TARGET CLASS'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()

# %%
s.fit(df.drop("TARGET CLASS",axis=1))
# Out:
# StandardScaler()

# %%
feature=s.transform(df.drop("TARGET CLASS",axis=1))

# %%
df1=pd.DataFrame(feature,columns=df.columns[:-1])

# %%
from sklearn.model_selection  import train_test_split
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
X=df1
y=df["TARGET CLASS"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier(n_neighbors=5)

# %%
k.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
p=k.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       155
#            1       0.96      0.94      0.95       175
#
#     accuracy                           0.95       330
#    macro avg       0.95      0.95      0.95       330
# weighted avg       0.95      0.95      0.95       330

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,p))
# Out:
# [[149   6]
#  [ 10 165]]

# %%
X=df1
y=df["TARGET CLASS"]
